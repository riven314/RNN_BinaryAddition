# %% [markdown]
# ### Summary
# - Train the final model selected in *hyperparameters_analysis.ipynb* with full training set <br>
# - Number of batch = 46 as training sample size has to be divisible by batch size
# - Number of epoch = 30
# - Test the robustness of the model by training the model with 10 different test sets

# %%
from macro_util import *
import matplotlib.pyplot as plt
# %matplotlib inline

FILENAME = 'data/data.txt'

# %%
# shuffle test set at random seed 100
hyperparam_cache = {'filename': FILENAME,
                                'batch_size': 64,
                                'n_mb': 46,
                                'num4test': 1000,
                                'n_epoch': 30,
                                'is_flip': True,
                                'hidden_dims': [4, 4, 4],
                                'hidden_activation': 'tanh',
                                'init_method': 'xavier',
                                'lr': 0.01, 
                                'opt_method': 'adam',
                                'is_print_metrics': False,
                                'shuff_seed': 100} 
macro_run(hyperparam_cache)
# Out:
# x and y are flipped upsided down
# x shape = (5000, 8, 2)
# y shape = (5000, 8)
# train_x shape = (2944, 8, 2)
# train_y shape = (2944, 8)
# test_x shape = (1000, 8, 2)
# test_y shape = (1000, 8)
# test accuracy: 0.9874
# test loss: 0.3662

# %%
# shuffle test set at random seed 101
hyperparam_cache = {'filename': FILENAME,
                                'batch_size': 64,
                                'n_mb': 46,
                                'num4test': 1000,
                                'n_epoch': 30,
                                'is_flip': True,
                                'hidden_dims': [4, 4, 4],
                                'hidden_activation': 'tanh',
                                'init_method': 'xavier',
                                'lr': 0.01, 
                                'opt_method': 'adam',
                                'is_print_metrics': False,
                                'shuff_seed': 101}
macro_run(hyperparam_cache)
# Out:
# x and y are flipped upsided down
# x shape = (5000, 8, 2)
# y shape = (5000, 8)
# train_x shape = (2944, 8, 2)
# train_y shape = (2944, 8)
# test_x shape = (1000, 8, 2)
# test_y shape = (1000, 8)
# test accuracy: 0.9741
# test loss: 0.8120

# %%
# shuffle test set at random seed 102
hyperparam_cache = {'filename': FILENAME,
                                'batch_size': 64,
                                'n_mb': 46,
                                'num4test': 1000,
                                'n_epoch': 30,
                                'is_flip': True,
                                'hidden_dims': [4, 4, 4],
                                'hidden_activation': 'tanh',
                                'init_method': 'xavier',
                                'lr': 0.01, 
                                'opt_method': 'adam',
                                'is_print_metrics': False,
                                'shuff_seed': 102}
macro_run(hyperparam_cache)
# Out:
# x and y are flipped upsided down
# x shape = (5000, 8, 2)
# y shape = (5000, 8)
# train_x shape = (2944, 8, 2)
# train_y shape = (2944, 8)
# test_x shape = (1000, 8, 2)
# test_y shape = (1000, 8)
# test accuracy: 0.9988
# test loss: 0.1016

# %%
# shuffle test set at random seed 103
hyperparam_cache = {'filename': FILENAME,
                                'batch_size': 64,
                                'n_mb': 46,
                                'num4test': 1000,
                                'n_epoch': 30,
                                'is_flip': True,
                                'hidden_dims': [4, 4, 4],
                                'hidden_activation': 'tanh',
                                'init_method': 'xavier',
                                'lr': 0.01, 
                                'opt_method': 'adam',
                                'is_print_metrics': False,
                                'shuff_seed': 103}
macro_run(hyperparam_cache)
# Out:
# x and y are flipped upsided down
# x shape = (5000, 8, 2)
# y shape = (5000, 8)
# train_x shape = (2944, 8, 2)
# train_y shape = (2944, 8)
# test_x shape = (1000, 8, 2)
# test_y shape = (1000, 8)
# test accuracy: 0.9395
# test loss: 0.9972

# %%
# shuffle test set at random seed 104
hyperparam_cache = {'filename': FILENAME,
                                'batch_size': 64,
                                'n_mb': 46,
                                'num4test': 1000,
                                'n_epoch': 30,
                                'is_flip': True,
                                'hidden_dims': [4, 4, 4],
                                'hidden_activation': 'tanh',
                                'init_method': 'xavier',
                                'lr': 0.01, 
                                'opt_method': 'adam',
                                'is_print_metrics': False,
                                'shuff_seed': 104}
macro_run(hyperparam_cache)
# Out:
# x and y are flipped upsided down
# x shape = (5000, 8, 2)
# y shape = (5000, 8)
# train_x shape = (2944, 8, 2)
# train_y shape = (2944, 8)
# test_x shape = (1000, 8, 2)
# test_y shape = (1000, 8)
# test accuracy: 0.9690
# test loss: 0.5529

# %% [markdown]
# ### Conclusion
# The final model is shown to be robust over different test sets.
